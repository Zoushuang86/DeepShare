# %%
from PIL import Image
import os

# %%
Image.open(r'E:\桌面\1.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1208x535 at 0x25FEDAE95C8>

# %%
Image.open(r'E:\桌面\2.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=661x513 at 0x25FEDB82948>

# %% [markdown]
# ### 在VOCdevkit/VOC2012下有5个文件夹

# %%
Image.open(r'E:\桌面\3.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=782x217 at 0x25FEDBECBC8>

# %% [markdown]
# #### 1. Annotations文件夹中存放的是xml格式的标签文件，每一个xml文件都对应于JPEGImages文件夹中的一张图片，共计17125个文件。
# .xml文件中的segmented参数代表是否为分割可用图片，0为不可用，1为可用

# %%
Image.open(r'E:\桌面\4.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=733x63 at 0x25FEDC1F248>

# %%
Image.open(r'E:\桌面\5.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=535x435 at 0x25FEDC1F948>

# %% [markdown]
# #### 2. ImageSets存放的是每一种类型的challenge对应的图像数据。
# Action：存放的是人的动作（running、jumping等等）
#
# Layout：存放的是具有人体部位的数据（人的head、hand、feet等等）
#
# Main：存放的是图像物体识别的数据，总共分为20类
#
# Segmentation：存放的是可用于分割的数据

# %%
Image.open(r'E:\桌面\6.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=550x123 at 0x25FEDC1FE88>

# %% [markdown]
# 主要看Segmentation文件夹。其中包含了train.txt（1416张图）、val.txt（1449张图）和trainval.txt（2913张图）三个文本文件，里面储存的是用于语义分割的图片的名字（无扩展名）。train和val两者没有交集，即训练数据和验证数据不能有重复，随机产生而trainval则是两者的总和

# %%
Image.open(r'E:\桌面\7.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=732x93 at 0x25FEDC24488>

# %%
Image.open(r'E:\桌面\8.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=160x143 at 0x25FEDC24A08>

# %% [markdown]
# #### 3. JPEGImages文件夹中包含了PASCAL VOC提供的所有的jpg图片，共计17125张，包括了训练和测试图片。
#
# 这些图像都以“年份_编号.jpg”格式命名。
#
# 图片的像素尺寸大小不一，但是横向图的尺寸大约在500×375左右，纵向图的尺寸大约在375×500左右，长宽均不会超过512

# %%
Image.open(r'E:\桌面\9.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1436x219 at 0x25FEDC2A048>

# %% [markdown]
# #### 4. SegmentationClass保存了分割后的标签图（2913张png图片），标注出了每一个像素属于哪一个类别

# %%
Image.open(r'E:\桌面\10.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1433x216 at 0x25FEDC2A608>

# %% [markdown]
# #### 5. SegmentationObject保存了分割后的标签图（2913张png图片），标注出了每一个像素属于哪一个具体的物体

# %%
Image.open(r'E:\桌面\11.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1432x221 at 0x25FEDC2AC48>

# %%
Image.open(r'E:\桌面\12.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=681x431 at 0x25FEDC2C248>
